# %%
import numpy as np
import pandas as pd

# %%
datos={'peliculas':['The Batman','Creed III','The Whale','Spiderman','Dias de Santiago'],
      'recaudacion':[90000,60000,100000,80000,95000],'prod':['DC','Universal','A24',
                                                            'Sony','X']}

# %%
datos
# Out:
# {'peliculas': ['The Batman',
#   'Creed III',
#   'The Whale',
#   'Spiderman',
#   'Dias de Santiago'],
#  'recaudacion': [90000, 60000, 100000, 80000, 95000],
#  'prod': ['DC', 'Universal', 'A24', 'Sony', 'X']}

# %%
pelis=pd.DataFrame(datos)

# %%
type(pelis)
pelis
# Out:
#           peliculas  recaudacion       prod
# 0        The Batman        90000         DC
# 1         Creed III        60000  Universal
# 2         The Whale       100000        A24
# 3         Spiderman        80000       Sony
# 4  Dias de Santiago        95000          X

# %%
pelis.to_csv('pelis.csv') # exportamos el dataframe

# %%
pips=pd.read_excel('pips.xlsx')
type(pips)
# Out:
# pandas.core.frame.DataFrame

# %%
pips.head() # solo muestra las prmeras 5 observaciones
# Out:
#                      Gobierno regional  \
# 0                          LA LIBERTAD
# 1                             AREQUIPA
# 2                             AREQUIPA
# 3  PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                             AYACUCHO
#
#                                             Proyecto Registro de cierre  \
# 0         2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                    2088142-MAJES SIGUAS - II ETAPA                 NO
# 2  2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3  2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
#
#    Monto viable  Costo actualizado  % Var Costo  Devengo acum  Avanc financ %  \
# 0  1.847407e+09       3.148963e+09     0.704531  8.260285e+08       26.231764
# 1  1.338420e+09       2.431439e+09     0.816649  7.141256e+08       29.370494
# ...

# %%
 pips.tail() # las ultimas 5 observaciones
# Out:
#      Gobierno regional                                           Proyecto  \
# 1937          AMAZONAS  2553402-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1938          AMAZONAS  2553393-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1939          AMAZONAS  2553377-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1940          AMAZONAS  2552901-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1941              LIMA  2106392-CONSTRUCCIÓN Y EQUIPAMIENTO DEL HOSPIT...
#
#      Registro de cierre  Monto viable  Costo actualizado  % Var Costo  \
# 1937                 NO        2200.0             2200.0          0.0
# 1938                 NO        2200.0             2200.0          0.0
# 1939                 NO        2200.0             2200.0          0.0
# 1940                 NO        2200.0             2200.0          0.0
# 1941                 NO           0.0        219185051.0          NaN
#
#       Devengo acum  Avanc financ %  Avanc físico %  Días de retraso
# ...

# %%
pips.info() # se puede los tipos de datos de cada una de las variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gobierno regional   1940 non-null   object
#  1   Proyecto            1942 non-null   object
#  2   Registro de cierre  1942 non-null   object
#  3   Monto viable        1942 non-null   float64
#  4   Costo actualizado   1942 non-null   float64
#  5   % Var Costo         1941 non-null   float64
#  6   Devengo acum        1942 non-null   float64
#  7   Avanc financ %      1942 non-null   float64
#  8   Avanc físico %      1942 non-null   float64
#  9   Días de retraso     1942 non-null   int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 151.8+ KB

# %%
# dimensiones del dataframe
pips.shape
# Out:
# (1942, 10)

# %%
# Contar valores
pips['Registro de cierre'].value_counts() # Realizar un recuento de la variable en cuestion
# Out:
# NO    1806
# SI     136
# Name: Registro de cierre, dtype: int64

# %%
# Extraer datos
# .loc

pips.loc[0:12,['Gobierno regional','Registro de cierre','Proyecto']]
# Out:
#                       Gobierno regional Registro de cierre  \
# 0                           LA LIBERTAD                 NO
# 1                              AREQUIPA                 NO
# 2                              AREQUIPA                 NO
# 3   PROVINCIA CONSTITUCIONAL DEL CALLAO                 NO
# 4                              AYACUCHO                 SI
# 5                              MOQUEGUA                 NO
# 6                              AREQUIPA                 NO
# 7                                 CUSCO                 NO
# 8                                  PUNO                 NO
# 9                               UCAYALI                 NO
# 10                                CUSCO                 SI
# 11                                JUNIN                 NO
# 12                                CUSCO                 NO
#
#                                              Proyecto
# 0          2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA
# ...

# %%
# .iloc
pips.iloc[0:10,'Proyecto']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     872 try:
# --> 873     self._validate_key(k, i)
#     874 except ValueError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexing.py:1483, in _iLocIndexer._validate_key(self, key, axis)
#    1482 else:
# -> 1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 # .iloc
# ...

# %%
pips.iloc[0:10,0:4]
# Out:
#                      Gobierno regional  \
# 0                          LA LIBERTAD
# 1                             AREQUIPA
# 2                             AREQUIPA
# 3  PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                             AYACUCHO
# 5                             MOQUEGUA
# 6                             AREQUIPA
# 7                                CUSCO
# 8                                 PUNO
# 9                              UCAYALI
#
#                                             Proyecto Registro de cierre  \
# 0         2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                    2088142-MAJES SIGUAS - II ETAPA                 NO
# 2  2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3  2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# 5  2046177-MEJORAMIENTO DE LA RED VIAL DEPARTAMEN...                 NO
# ...

# %%
# Ejercicio 1
'''me permite hacer un recuento 
agrupado por variables'''
pips.loc[:,['Gobierno regional','Registro de cierre']].value_counts()
# Out:
# Gobierno regional                    Registro de cierre
# LIMA                                 NO                    202
# AYACUCHO                             NO                    117
# AREQUIPA                             NO                    107
# APURIMAC                             NO                     97
# HUANCAVELICA                         NO                     94
# AMAZONAS                             NO                     92
# CUSCO                                NO                     87
# CAJAMARCA                            NO                     86
# SAN MARTIN                           NO                     83
# HUANUCO                              NO                     81
# JUNIN                                NO                     76
# LORETO                               NO                     76
# UCAYALI                              NO                     69
# PIURA                                NO                     65
# ...

# %%
# Filtros/Condicion
x=pips['Registro de cierre']=='SI'
pips[x]
# Out:
#             GORE                                           Proyecto  \
# 4       AYACUCHO  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...
# 10         CUSCO  2164798-MEJORAMIENTO DE LA TRANSITABILIDAD PEA...
# 29         PIURA                                            #ERROR!
# 35         CUSCO  2230327-MEJORAMIENTO DE LA CARRETERA HUANCARAN...
# 44        LORETO  2056395-MEJORAMIENTO DE LOS SERVICIOS DE SALUD...
# ...          ...                                                ...
# 1883   CAJAMARCA  2465378-REMODELACION DE LOSA DEPORTIVA; EN EL(...
# 1886  SAN MARTIN                                            #ERROR!
# 1907      LORETO  2493461-RENOVACION DE VEREDA; EN EL(LA) COMUNI...
# 1910         ICA  2520247-ADQUISICION DE CONGELADORA VERTICAL; E...
# 1931      LORETO  2525479-ADQUISICION DE TERRENO; EN EL(LA) IE 2...
#
#      Registro de cierre  Monto aprobado  Costo actualizado  % Var Costo  \
# 4                    SI    3.784391e+08       4.586711e+08     0.212008
# ...

# %%
pips[-x]
# Out:
#                         Gobierno regional  \
# 0                             LA LIBERTAD
# 1                                AREQUIPA
# 2                                AREQUIPA
# 3     PROVINCIA CONSTITUCIONAL DEL CALLAO
# 5                                MOQUEGUA
# ...                                   ...
# 1937                             AMAZONAS
# 1938                             AMAZONAS
# 1939                             AMAZONAS
# 1940                             AMAZONAS
# 1941                                 LIMA
#
#                                                Proyecto Registro de cierre  \
# 0            2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                       2088142-MAJES SIGUAS - II ETAPA                 NO
# 2     2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3     2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 5     2046177-MEJORAMIENTO DE LA RED VIAL DEPARTAMEN...                 NO
# ...

# %%
x=pelis['peliculas'].isin(['The Batman','Dias de Santiago'])

pelis.loc[x]
# Out:
#           peliculas  recaudacion prod
# 0        The Batman        90000   DC
# 4  Dias de Santiago        95000    X

# %%
pips.columns
# Out:
# Index(['Gobierno regional', 'Proyecto', 'Registro de cierre', 'Monto viable',
#        'Costo actualizado', '% Var Costo', 'Devengo acum', 'Avanc financ %',
#        'Avanc físico %', 'Días de retraso'],
#       dtype='object')

# %%
# Variables NA
x=pips['% Var Costo'].isna()
pips.loc[x]
# Out:
#      Gobierno regional                                           Proyecto  \
# 1941              LIMA  2106392-CONSTRUCCIÓN Y EQUIPAMIENTO DEL HOSPIT...
#
#      Registro de cierre  Monto viable  Costo actualizado  % Var Costo  \
# 1941                 NO           0.0        219185051.0          NaN
#
#       Devengo acum  Avanc financ %  Avanc físico %  Días de retraso
# 1941   214703109.6       97.955179            97.6                0

# %%
x=pips['Gobierno regional'].isna()
pips.loc[x]
# Out:
#      Gobierno regional                                           Proyecto  \
# 1366               NaN  2353383-REHABILITACIÓN DE LA CARRETERA DE ACCE...
# 1705               NaN  2353376-REHABILITACION DE SERVICIO DE TRANSITA...
#
#      Registro de cierre  Monto viable  Costo actualizado  % Var Costo  \
# 1366                 NO    1912609.45         1912609.45     0.000000
# 1705                 SI     450355.86          420776.89    -0.065679
#
#       Devengo acum  Avanc financ %  Avanc físico %  Días de retraso
# 1366    1548287.43       80.951573           80.42             1512
# 1705     323699.97       76.929123           73.31                0

# %%
x=pips['Gobierno regional'].notna()
pips.loc[x]
# Out:
#                         Gobierno regional  \
# 0                             LA LIBERTAD
# 1                                AREQUIPA
# 2                                AREQUIPA
# 3     PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                                AYACUCHO
# ...                                   ...
# 1937                             AMAZONAS
# 1938                             AMAZONAS
# 1939                             AMAZONAS
# 1940                             AMAZONAS
# 1941                                 LIMA
#
#                                                Proyecto Registro de cierre  \
# 0            2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                       2088142-MAJES SIGUAS - II ETAPA                 NO
# 2     2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3     2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4     2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# ...

# %%
# Cambiar nombres de las columnas
pips.rename(columns={'Gobierno regional':'GORE','Monto viable':'Monto aprobado'},inplace=True)
pips
# Out:
#                                      GORE  \
# 0                             LA LIBERTAD
# 1                                AREQUIPA
# 2                                AREQUIPA
# 3     PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                                AYACUCHO
# ...                                   ...
# 1937                             AMAZONAS
# 1938                             AMAZONAS
# 1939                             AMAZONAS
# 1940                             AMAZONAS
# 1941                                 LIMA
#
#                                                Proyecto Registro de cierre  \
# 0            2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                       2088142-MAJES SIGUAS - II ETAPA                 NO
# 2     2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3     2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4     2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# ...

# %%
pelis
# Out:
#           peliculas  recaudacion       prod
# 0        The Batman        90000         DC
# 1         Creed III        60000  Universal
# 2         The Whale       100000        A24
# 3         Spiderman        80000       Sony
# 4  Dias de Santiago        95000          X

# %%
pelis['recaudacion']=pelis['recaudacion'].replace({95000:40000})
pelis
# Out:
#           peliculas  recaudacion       prod
# 0        The Batman        90000         DC
# 1         Creed III        60000  Universal
# 2         The Whale       100000        A24
# 3         Spiderman        80000       Sony
# 4  Dias de Santiago        40000          X

# %%
genero=['accion','deporte','drama','ficcion','drama']
pelis['Genero']=genero
pelis
# Out:
#           peliculas  recaudacion       prod   Genero
# 0        The Batman        90000         DC   accion
# 1         Creed III        60000  Universal  deporte
# 2         The Whale       100000        A24    drama
# 3         Spiderman        80000       Sony  ficcion
# 4  Dias de Santiago        40000          X    drama

# %%
pelis.drop('Genero',axis=1,inplace=True)
pelis
# Out:
#           peliculas  recaudacion       prod
# 0        The Batman        90000         DC
# 1         Creed III        60000  Universal
# 2         The Whale       100000        A24
# 3         Spiderman        80000       Sony
# 4  Dias de Santiago        40000          X
